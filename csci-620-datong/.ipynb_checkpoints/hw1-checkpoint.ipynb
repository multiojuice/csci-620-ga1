# %%
import pandas as pd

df = pd.read_excel(r'C:\studylife\CSCI- 620\assigments\assign1\allRaces.xlsx', engine='openpyxl')
df.columns = df.iloc[4]
df_all = df.iloc[6:20, 0:17]
df_all
# Out:
# 4                   NaN   Total None 1st - 4th grade 5th - 6th grade  \
# 6    .18 years and over  252117  771            1414            2933
# 7      ..18 to 24 years   29059   46              33              89
# 8    .25 years and over  223058  725            1381            2844
# 9      ..25 to 29 years   23027   25              35              67
# 10     ..30 to 34 years   22233   58              51             170
# 11     ..35 to 39 years   21560   61              88             235
# 12     ..40 to 44 years   19852   66              96             289
# 13     ..45 to 49 years   19621   73             112             290
# 14     ..50 to 54 years   19967   57             130             291
# 15     ..55 to 59 years   21142   60             164             315
# 16     ..60 to 64 years   21015   76             148             266
# 17     ..65 to 69 years   17700   49             131             259
# 18     ..70 to 74 years   14569   66             157             235
# ...

# %%
df_all['under high school'] = df_all.iloc[:,2:9].sum(axis=1)
df_all['high school to bechelor'] = df_all.iloc[:,9:13].sum(axis=1)
df_all['up bechelor'] = df_all.iloc[:,13:17].sum(axis=1)
print('All Race Sum')
df_all.iloc[:,17:20]
# Out:
# All Race Sum
# 4   under high school  high school to bechelor  up bechelor
# 6             24627.0                 139771.0      87718.0
# 7              4421.0                  20621.0       4017.0
# 8             20208.0                 119149.0      83701.0
# 9              1207.0                  12797.0       9024.0
# 10             1487.0                  11179.0       9567.0
# 11             1738.0                  10458.0       9362.0
# 12             1859.0                   9868.0       8125.0
# 13             1766.0                   9797.0       8057.0
# 14             1817.0                  10439.0       7709.0
# 15             2076.0                  11963.0       7104.0
# 16             1990.0                  12178.0       6849.0
# 17             1614.0                   9839.0       6246.0
# 18             1423.0                   8118.0       5027.0
# 19             3231.0                  12513.0       6630.0
