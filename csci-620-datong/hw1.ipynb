# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel(r'C:\studylife\CSCI- 620\assigments\assign1\whiteAloneCom.xlsx', engine='openpyxl')
df.columns = df.iloc[4]
df_all = df.iloc[6:20, 0:17]
df_male = df.iloc[21:34, 0:17]
df_female = df.iloc[36:49, 0:17]
# group_interval = [[0,3],[3,6],[6,9],[9,'ending']]

def groupPicture(df):
    df_all['UN'] = df_all.iloc[:,2:9].sum(axis=1)
    df_all['BE'] = df_all.iloc[:,9:13].sum(axis=1)
    df_all['UP'] = df_all.iloc[:,13:17].sum(axis=1)
    df_summary_col = df_all.iloc[:,17:20]
    df_summary_col
    figure, axis = plt.subplots(2, 2)
    axis[0,0].plot(df_summary_col.iloc[0:3,:].sum())
    axis[0,0].set_title('18-25')

    axis[0,1].plot(df_summary_col.iloc[3:6,:].sum() )
    axis[0,1].set_title('25-34')

    axis[1,0].plot(df_summary_col.iloc[6:9,:].sum())
    axis[1,0].set_title('35-55')

    axis[1,1].plot(df_summary_col.iloc[9:,:].sum())
    axis[1,1].set_title('over 55')

    plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
    plt.show()
    figure.savefig("whiteAloneCom_female.png")
    return df_summary_col

# %%
col_sum = groupPicture(df_female)

# %%
df_summary_col.iloc[0:3,:].sum().plot.bar()
plt.title('18-25')
# Out:
# Text(0.5, 1.0, '18-25')

# %%
df_summary_col.iloc[3:6,:].sum().plot.bar()
plt.title('25-34')
# Out:
# Text(0.5, 1.0, '25-34')

# %%
df_summary_col.iloc[6:9,:].sum().plot.bar()
plt.title('35-55')
# Out:
# Text(0.5, 1.0, '35-55')

# %%
df_summary_col.iloc[9:,:].sum().plot.bar()
plt.title('over 55')
# Out:
# Text(0.5, 1.0, 'over 55')
