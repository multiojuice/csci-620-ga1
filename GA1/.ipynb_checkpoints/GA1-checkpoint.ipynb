# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
ls
# Out:
# GA1.ipynb         table-2-1.xlsx    ~$table-2-1.xlsx
# table-1-1.xlsx    ~$table-1-1.xlsx

# %%
census_data = pd.read_excel('table-2-1.xlsx', header=5, skipfooter=10, index_col=0)

# %%
census_data
# Out:
#                                         Unnamed: 1  None - 8th grade  \
# Total                                     223058.0            7895.0
# NaN                                            NaN               NaN
# Marital Status                                 NaN               NaN
# .Married, spouse present                  127930.0            4226.0
# .Married, spouse absent, not separated      3286.0             245.0
# ...                                            ...               ...
# .Professional and business services        17600.0             406.0
# .Educational and health services           32334.0             182.0
# .Leisure and hospitality                    9191.0             432.0
# .Other services                             6476.0             184.0
# .Public administration                      7206.0              26.0
#
#                                         9th - 11th grade2  \
# Total                                             12313.0
# NaN                                                   NaN
# Marital Status                                        NaN
# .Married, spouse present                           5690.0
# .Married, spouse absent, not separated              199.0
# ...                                                   ...
# .Professional and business services                 563.0
# .Educational and health services                    540.0
# .Leisure and hospitality                            666.0
# .Other services                                     336.0
# .Public administration                               71.0
#
#                                         High school graduate  \
# Total                                                61597.0
# NaN                                                      NaN
# Marital Status                                           NaN
# .Married, spouse present                             31970.0
# .Married, spouse absent, not separated                 923.0
# ...                                                      ...
# .Professional and business services                   2690.0
# .Educational and health services                      4601.0
# .Leisure and hospitality                              3126.0
# .Other services                                       2074.0
# .Public administration                                1164.0
#
#                                         Some college, no degree  \
# Total                                                   33986.0
# NaN                                                         NaN
# Marital Status                                              NaN
# .Married, spouse present                                18068.0
# .Married, spouse absent, not separated                    426.0
# ...                                                         ...
# .Professional and business services                      1996.0
# .Educational and health services                         3523.0
# .Leisure and hospitality                                 1610.0
# .Other services                                           971.0
# .Public administration                                   1187.0
#
#                                         Associate's degree3  \
# Total                                               23566.0
# NaN                                                     NaN
# Marital Status                                          NaN
# .Married, spouse present                            13714.0
# .Married, spouse absent, not separated                317.0
# ...                                                     ...
# .Professional and business services                  1497.0
# .Educational and health services                     4275.0
# .Leisure and hospitality                              912.0
# .Other services                                       820.0
# .Public administration                                991.0
#
#                                         Bachelor's degree  Master's degree  \
# Total                                             52164.0          23516.0
# NaN                                                   NaN              NaN
# Marital Status                                        NaN              NaN
# .Married, spouse present                          32361.0          16169.0
# .Married, spouse absent, not separated              693.0            337.0
# ...                                                   ...              ...
# .Professional and business services                6444.0           2619.0
# .Educational and health services                   9241.0           7037.0
# .Leisure and hospitality                           1927.0            423.0
# .Other services                                    1301.0            613.0
# .Public administration                             2235.0           1116.0
#
#                                        Professional degree Doctoral degree
# Total                                                 3362            4659
# NaN                                                    NaN             NaN
# Marital Status                                         NaN             NaN
# .Married, spouse present                              2354            3380
# .Married, spouse absent, not separated                  50              96
# ...                                                    ...             ...
# .Professional and business services                    773             612
# .Educational and health services                      1070            1867
# .Leisure and hospitality                                51              45
# .Other services                                         73             104
# .Public administration                                 210             206
#
# [68 rows x 10 columns]

# %%
# subsetting into marital data
marital_df = census_data[3:9]
del marital_df['Unnamed: 1']
marital_df.head()
# Out:
#                                         None - 8th grade  9th - 11th grade2  \
# .Married, spouse present                          4226.0             5690.0
# .Married, spouse absent, not separated             245.0              199.0
# .Separated                                         306.0              501.0
# .Widowed                                          1044.0             1361.0
# .Divorced                                          626.0             1571.0
#
#                                         High school graduate  \
# .Married, spouse present                             31970.0
# .Married, spouse absent, not separated                 923.0
# .Separated                                            1473.0
# .Widowed                                              5335.0
# .Divorced                                             7719.0
#
#                                         Some college, no degree  \
# .Married, spouse present                                18068.0
# .Married, spouse absent, not separated                    426.0
# .Separated                                                728.0
# .Widowed                                                 2452.0
# .Divorced                                                4629.0
#
#                                         Associate's degree3  \
# .Married, spouse present                            13714.0
# .Married, spouse absent, not separated                317.0
# .Separated                                            384.0
# .Widowed                                             1299.0
# .Divorced                                            3319.0
#
#                                         Bachelor's degree  Master's degree  \
# .Married, spouse present                          32361.0          16169.0
# .Married, spouse absent, not separated              693.0            337.0
# .Separated                                          575.0            237.0
# .Widowed                                           2072.0            885.0
# .Divorced                                          4707.0           2025.0
#
#                                        Professional degree Doctoral degree
# .Married, spouse present                              2354            3380
# .Married, spouse absent, not separated                  50              96
# .Separated                                              46              24
# .Widowed                                               121             144
# .Divorced                                              298             311

# %%
to_use = ['.Married, spouse present', '.Divorced']
percentages = pd.DataFrame()

# looking at married w/ spous present and divorced
for row in to_use:
    data = []
    # iterate through each column
    for col in marital_df.columns:
        # sum the rows to get denominator for percentage
        total = marital_df.loc[row].sum()
        data.append((marital_df.at[row, col]/total) * 100)
    # create dataframe to concat w/ marital df
    data_df = pd.DataFrame([data], columns=marital_df.columns)
    percentages = pd.concat([percentages,data_df], axis=0, ignore_index=False)
    percentages.rename(index={0: row + " percentages"}, inplace=True)
    
percentages
# Out:
#                                       None - 8th grade  9th - 11th grade2  \
# .Married, spouse present percentages          3.303317           4.447675
# .Divorced percentages                         2.483634           6.232890
#
#                                       High school graduate  \
# .Married, spouse present percentages             24.989838
# .Divorced percentages                            30.624876
#
#                                       Some college, no degree  \
# .Married, spouse present percentages                14.123128
# .Divorced percentages                               18.365404
#
#                                       Associate's degree3  Bachelor's degree  \
# .Married, spouse present percentages            10.719757          25.295469
# .Divorced percentages                           13.168022          18.674866
#
#                                       Master's degree  Professional degree  \
# .Married, spouse present percentages        12.638746             1.840040
# .Divorced percentages                        8.034120             1.182305
#
#                                       Doctoral degree
# .Married, spouse present percentages         2.642029
# .Divorced percentages                        1.233882

# %%
# looking at married, spouse present
marital_df.iloc[0].plot(kind="bar", title='Married, spouse present')

# %%
# looking at divorced
marital_df.iloc[4].plot(kind="bar", title='Divorced')

# %%
# subsetting into employment data
employment_df = census_data[38:40]
del employment_df['Unnamed: 1']
employment_df.head()
# Out:
#             None - 8th grade  9th - 11th grade2  High school graduate  \
# Employed              3142.0             5194.0               32930.0
# Unemployed             279.0              491.0                2048.0
#
#             Some college, no degree  Associate's degree3  Bachelor's degree  \
# Employed                    19733.0              15403.0            36695.0
# Unemployed                   1077.0                652.0             1175.0
#
#             Master's degree Professional degree Doctoral degree
# Employed            16562.0                2495            3447
# Unemployed            449.0                  59              69

# %%
employment_df.iloc[0].plot(kind="bar", title='Employed')

# %%
employment_df.iloc[1].plot(kind="bar", title='Unemployed')

# %%
emp_to_use = ['Employed', 'Unemployed']
emp_percentages = pd.DataFrame()

# looking at married w/ spous present and divorced
for row in emp_to_use:
    data = []
    # iterate through each column
    for col in employment_df.columns:
        # sum the rows to get denominator for percentage
        total = employment_df.loc[row].sum()
        data.append((employment_df.at[row, col]/total) * 100)
    # create dataframe to concat w/ marital df
    data_df = pd.DataFrame([data], columns=employment_df.columns)
    emp_percentages = pd.concat([emp_percentages,data_df], axis=0, ignore_index=False)
    emp_percentages.rename(index={0: row + " percentages"}, inplace=True)
    
emp_percentages
# Out:
#                         None - 8th grade  9th - 11th grade2  \
# Employed percentages            2.317092           3.830355
# Unemployed percentages          4.429274           7.794888
#
#                         High school graduate  Some college, no degree  \
# Employed percentages               24.284482                14.552253
# Unemployed percentages             32.513097                17.097952
#
#                         Associate's degree3  Bachelor's degree  \
# Employed percentages              11.359061          27.061010
# Unemployed percentages            10.350849          18.653755
#
#                         Master's degree  Professional degree  Doctoral degree
# Employed percentages          12.213774             1.839957         2.542017
# Unemployed percentages         7.128116             0.936657         1.095412
